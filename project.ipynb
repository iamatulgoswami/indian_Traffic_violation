# %% [markdown]
# # City Traffic Signal Violation Analysis
# + From: Minor 1 – Pandas
# + Extension: Analyze violation counts → traffic safety study.
# + Add-ons: Bar charts, stats summary.
# + Difficulty: Medium

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("indian_Traffic_violation.csv")

# %%
df.head()
# Out:
#          date   city signal_id         location     violation_type  \
# 0  2024-01-01  Delhi   SIG-101  Connaught Place  Red Light Jumping
# 1  2024-01-01  Delhi   SIG-102    Kashmere Gate           Speeding
# 2  2024-01-02  Delhi   SIG-101  Connaught Place  Red Light Jumping
# 3  2024-01-02  Delhi   SIG-103     Lajpat Nagar          No Helmet
# 4  2024-01-03  Delhi   SIG-104            Saket     Signal Jumping
#
#   vehicle_type  violation_count
# 0          Car               15
# 1         Bike               22
# 2         Bike               18
# 3         Bike               25
# 4         Auto               12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             20 non-null     object
#  1   city             20 non-null     object
#  2   signal_id        20 non-null     object
#  3   location         20 non-null     object
#  4   violation_type   20 non-null     object
#  5   vehicle_type     20 non-null     object
#  6   violation_count  20 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB

# %%
violation_counts = df['violation_type'].value_counts()
violation_counts
# Out:
# violation_type
# Speeding             5
# Red Light Jumping    4
# No Helmet            3
# Signal Jumping       3
# Wrong Lane           3
# No Seatbelt          2
# Name: count, dtype: int64

# %%
vehicle_counts = df['vehicle_type'].value_counts()
vehicle_counts
# Out:
# vehicle_type
# Bike    9
# Car     8
# Auto    2
# Bus     1
# Name: count, dtype: int64

# %%
signal_counts = df['signal_id'].value_counts()
signal_counts
# Out:
# signal_id
# SIG-101    5
# SIG-102    4
# SIG-103    4
# SIG-104    4
# SIG-105    3
# Name: count, dtype: int64

# %%
location_counts = df['location'].value_counts()
location_counts
# Out:
# location
# Connaught Place    5
# Kashmere Gate      4
# Lajpat Nagar       4
# Saket              4
# Rohini             3
# Name: count, dtype: int64

# %%
violation_counts.plot(kind='bar')
plt.title("Traffic Violations by Type")
plt.xlabel("Violation Type")
plt.ylabel("Number of Violations")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
vehicle_counts.plot(kind='bar')
plt.title("Violations by Vehicle Type")
plt.xlabel("Vehicle Type")
plt.ylabel("Count")
plt.show()

# %%
violation_counts.idxmax()
# Out:
# 'Speeding'

# %%
location_counts.idxmax()
# Out:
# 'Connaught Place'

# %% [markdown]
# ## Conclusions
#
# - Red Light Jumping is the most common traffic violation.
# - Bikes are involved in the highest number of violations.
# - Connaught Place and Kashmere Gate are high-risk locations.
# - Repeated violations at the same signals indicate the need for stricter monitoring.
# - Traffic safety awareness and enforcement should be improved during peak hours.
